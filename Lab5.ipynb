# %%
# !wget https://raw.githubusercontent.com/kasprowski/deep2021/main/lecture5/roman/roman_numerals.py
# Out:
# --2022-02-03 00:28:32--  https://raw.githubusercontent.com/kasprowski/deep2021/main/lecture5/roman/roman_numerals.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2161 (2.1K) [text/plain]
# Saving to: ‘roman_numerals.py’
#
# roman_numerals.py   100%[===================>]   2.11K  --.-KB/s    in 0s
#
# 2022-02-03 00:28:32 (27.1 MB/s) - ‘roman_numerals.py’ saved [2161/2161]

# %%
# !wget https://raw.githubusercontent.com/kasprowski/deep2021/main/lecture5/roman/encoder.py
# Out:
# --2022-02-03 00:28:50--  https://raw.githubusercontent.com/kasprowski/deep2021/main/lecture5/roman/encoder.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1812 (1.8K) [text/plain]
# Saving to: ‘encoder.py’
#
# encoder.py          100%[===================>]   1.77K  --.-KB/s    in 0s
#
# 2022-02-03 00:28:50 (37.3 MB/s) - ‘encoder.py’ saved [1812/1812]

# %%
import random
from tensorflow.python.keras import layers
from tensorflow.python.keras.models import Sequential
import roman_numerals as cnv
import numpy as np
import random

# %%
from encoder import CharacterTable

# %%
# Parameters for the model and dataset.
DATASET_SIZE = 200
INPUT = 14
OUTPUT = 4
# object to encode roman numbers to one-hot 
romans = 'MDCLXVI '
rtable = CharacterTable(romans)

# object to encode arabic numbers to one-hot
chars = '0123456789 '
dtable = CharacterTable(chars)

# %%
seq_samples = []
seq_labels = []
used = []
repetitions = 0
generated = 0
print('Generating data...')
while len(seq_samples) < DATASET_SIZE:
    number = random.randint(1,200)
    # skip if already in the dataset
    if number in used: continue
    used.append(number)
    # roman input
    roman = cnv.convert(number) 
    roman += ' ' * (INPUT - len(roman))
    
    # arabic output
    arabic = str(number)
    arabic += ' ' * (OUTPUT - len(arabic)) 
    
    seq_samples.append(roman)
    seq_labels.append(arabic)
print('Total roman numbers:', len(seq_samples))
#print("samples",seq_samples)
#print("labels",seq_labels)
# Out:
# Generating data...
# Total roman numbers: 200

# %%
# one-hot encoding of all romans and arabic numbers
print('Vectorization...')
samples = np.zeros((DATASET_SIZE, INPUT, len(romans)), dtype=np.bool)
labels = np.zeros((DATASET_SIZE, OUTPUT, len(chars)), dtype=np.bool)
for i, sentence in enumerate(seq_samples):
    samples[i] = rtable.encode(sentence, INPUT)
for i, sentence in enumerate(seq_labels):
    labels[i] = dtable.encode(sentence, OUTPUT)
print("samples",samples.shape)    
print("labels",labels.shape)
# Out:
# Vectorization...
# samples (200, 14, 8)
# labels (200, 4, 11)

# %%
import sklearn.model_selection
(trainSamples, testSamples, trainLabels, testLabels) = sklearn.model_selection.train_test_split(samples,labels,random_state=42)
print("Training samples",len(trainSamples))
print("Test samples",len(testSamples))
# Out:
# Training samples 150
# Test samples 50

# %%
# Build the network
print('Build model...')
model = Sequential()
model.add(layers.LSTM(128, input_shape=(INPUT, len(romans))))
model.add(layers.RepeatVector(OUTPUT))
model.add(layers.LSTM(128, return_sequences=True))
model.add(layers.Dense(len(chars), activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Build model...
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               70144
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 4, 128)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 4, 128)            131584
# _________________________________________________________________
# dense (Dense)                (None, 4, 11)             1419
# =================================================================
# Total params: 203,147
# Trainable params: 203,147
# Non-trainable params: 0
# _________________________________________________________________

# %%
def avg(list):
    return sum(list)/len(list)

EPOCHS = 50
# Train the model each generation and show predictions against the validation dataset.
for iteration in range(1, 200):
    print()
    print('-' * 50)
    print('Iteration', iteration*EPOCHS)
    H = model.fit(trainSamples, trainLabels, batch_size=128, epochs=EPOCHS, 
                  validation_data=(testSamples, testLabels), verbose=0)
    print("Validation accuracy: {}".format(avg(H.history["val_accuracy"])))
    # Select 10 samples from the validation set at random to visualize errors.
    accuracy = 0
    for i in range(len(testSamples)):
        
        rowx, rowy = testSamples[np.array([i])], testLabels[np.array([i])]
        preds = model.predict_classes(rowx, verbose=0)
        roman = rtable.decode(rowx[0])
        correct = dtable.decode(rowy[0])
        prediction = dtable.decode(preds[0], calc_argmax=False)
        correctTxt = ""
        if correct == prediction:
            correctTxt+='OK!'
            accuracy+=1
        v = random.random()
        if v>0.9:
            print('expression:', roman, end=' ')
            print('correct:', correct, end=' ')
            print('predicted:', prediction, end=' ')
            print(correctTxt)
        
    print('accuracy=',accuracy,"/",len(testSamples),"=",accuracy/len(testSamples))
# Out:
# --------------------------------------------------
# Iteration 50
# Validation accuracy: 0.47040000081062316
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:454: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# expression: CLXXXIX        correct: 189  predicted: 166
# expression: CLII           correct: 152  predicted: 16
# expression: XXXI           correct: 31   predicted: 16
# expression: XLVI           correct: 46   predicted: 16
# expression: CLXIV          correct: 164  predicted: 166
# accuracy= 0 / 50 = 0.0
#
# --------------------------------------------------
# Iteration 100
# Validation accuracy: 0.5537000060081482
# expression: CLXX           correct: 170  predicted: 190
# expression: CXLIV          correct: 144  predicted: 196
# expression: XLVI           correct: 46   predicted: 62
# expression: XLVII          correct: 47   predicted: 33
# expression: CVIII          correct: 108  predicted: 13
# expression: CXLVII         correct: 147  predicted: 177
# accuracy= 0 / 50 = 0.0
#
# --------------------------------------------------
# Iteration 150
# Validation accuracy: 0.607700001001358
# expression: XCIV           correct: 94   predicted: 19
# expression: LXVII          correct: 67   predicted: 77
# expression: XXXI           correct: 31   predicted: 19
# expression: CXXIX          correct: 129  predicted: 111
# expression: LXIX           correct: 69   predicted: 19
# expression: XLIV           correct: 44   predicted: 84
# accuracy= 5 / 50 = 0.1
#
# --------------------------------------------------
# Iteration 200
# Validation accuracy: 0.6810999965667724
# expression: XCIV           correct: 94   predicted: 99
# expression: CI             correct: 101  predicted: 111
# expression: CLV            correct: 155  predicted: 155  OK!
# expression: CLII           correct: 152  predicted: 122
# expression: CVIII          correct: 108  predicted: 138
# accuracy= 6 / 50 = 0.12
#
# --------------------------------------------------
# Iteration 250
# Validation accuracy: 0.715900000333786
# expression: CLV            correct: 155  predicted: 155  OK!
# expression: CLII           correct: 152  predicted: 152  OK!
# expression: CXIII          correct: 113  predicted: 127
# accuracy= 12 / 50 = 0.24
#
# --------------------------------------------------
# Iteration 300
# Validation accuracy: 0.7534999990463257
# expression: CLXXVI         correct: 176  predicted: 174
# expression: LXXV           correct: 75   predicted: 75   OK!
# expression: XLVII          correct: 47   predicted: 67
# expression: CXLVII         correct: 147  predicted: 167
# expression: CLXXVIII       correct: 178  predicted: 188
# expression: XXI            correct: 21   predicted: 11
# accuracy= 15 / 50 = 0.3
#
# --------------------------------------------------
# Iteration 350
# Validation accuracy: 0.7916000020503998
# expression: LI             correct: 51   predicted: 55
# expression: CVI            correct: 106  predicted: 104
# expression: XXXI           correct: 31   predicted: 39
# expression: CXXVIII        correct: 128  predicted: 138
# expression: XLVII          correct: 47   predicted: 67
# expression: XCIII          correct: 93   predicted: 93   OK!
# accuracy= 15 / 50 = 0.3
#
# --------------------------------------------------
# Iteration 400
# Validation accuracy: 0.8243999910354615
# expression: LXXI           correct: 71   predicted: 71   OK!
# expression: LXVII          correct: 67   predicted: 67   OK!
# expression: CVIII          correct: 108  predicted: 117
# expression: XCIII          correct: 93   predicted: 93   OK!
# expression: CLXXVIII       correct: 178  predicted: 188
# expression: XXI            correct: 21   predicted: 29
# accuracy= 23 / 50 = 0.46
#
# --------------------------------------------------
# Iteration 450
# Validation accuracy: 0.8532000160217286
# expression: CXVII          correct: 117  predicted: 117  OK!
# expression: XCI            correct: 91   predicted: 99
# expression: CXLV           correct: 145  predicted: 145  OK!
# expression: XCIII          correct: 93   predicted: 93   OK!
# expression: XLIV           correct: 44   predicted: 44   OK!
# expression: XXI            correct: 21   predicted: 29
# accuracy= 26 / 50 = 0.52
#
# --------------------------------------------------
# Iteration 500
# Validation accuracy: 0.8574000167846679
# expression: LXXI           correct: 71   predicted: 71   OK!
# expression: CLII           correct: 152  predicted: 152  OK!
# expression: LXXV           correct: 75   predicted: 75   OK!
# expression: XXXVII         correct: 37   predicted: 38
# expression: XLI            correct: 41   predicted: 41   OK!
# accuracy= 25 / 50 = 0.5
#
# --------------------------------------------------
# Iteration 550
# Validation accuracy: 0.8606000137329102
# expression: CXVII          correct: 117  predicted: 117  OK!
# expression: LXXXIII        correct: 83   predicted: 88
# expression: LXVII          correct: 67   predicted: 67   OK!
# expression: CLXXVI         correct: 176  predicted: 176  OK!
# expression: CVIII          correct: 108  predicted: 107
# accuracy= 26 / 50 = 0.52
#
# --------------------------------------------------
# Iteration 600
# Validation accuracy: 0.8651000094413758
# expression: LI             correct: 51   predicted: 55
# expression: LXXXVII        correct: 87   predicted: 88
# expression: CLVIII         correct: 158  predicted: 158  OK!
# expression: XLVII          correct: 47   predicted: 67
# expression: LXXIII         correct: 73   predicted: 77
# expression: XXIV           correct: 24   predicted: 24   OK!
# expression: XXI            correct: 21   predicted: 29
# accuracy= 28 / 50 = 0.56
#
# --------------------------------------------------
# Iteration 650
# Validation accuracy: 0.8683000063896179
# expression: CXVII          correct: 117  predicted: 117  OK!
# expression: LXXXIII        correct: 83   predicted: 88
# expression: CXLIV          correct: 144  predicted: 144  OK!
# accuracy= 28 / 50 = 0.56
#
# --------------------------------------------------
# Iteration 700
# Validation accuracy: 0.8751999998092651
# expression: XXXI           correct: 31   predicted: 39
# expression: CLXXXIII       correct: 183  predicted: 183  OK!
# expression: CXIII          correct: 113  predicted: 113  OK!
# expression: LXIX           correct: 69   predicted: 69   OK!
# accuracy= 28 / 50 = 0.56
#
# --------------------------------------------------
# Iteration 750
# Validation accuracy: 0.8820999932289123
# expression: XCV            correct: 95   predicted: 60
# expression: CLXX           correct: 170  predicted: 170  OK!
# expression: LI             correct: 51   predicted: 51   OK!
# expression: CVI            correct: 106  predicted: 106  OK!
# expression: LXXXVII        correct: 87   predicted: 88
# expression: XCVI           correct: 96   predicted: 72
# expression: LXIX           correct: 69   predicted: 69   OK!
# expression: XXI            correct: 21   predicted: 29
# accuracy= 30 / 50 = 0.6
#
# --------------------------------------------------
# Iteration 800
# Validation accuracy: 0.8885999870300293
# expression: CLXXXIX        correct: 189  predicted: 181
# expression: XCI            correct: 91   predicted: 99
# expression: XVII           correct: 17   predicted: 17   OK!
# expression: XXXI           correct: 31   predicted: 39
# expression: LXXV           correct: 75   predicted: 75   OK!
# expression: CXXXII         correct: 132  predicted: 132  OK!
# expression: XLIV           correct: 44   predicted: 44   OK!
# expression: XXI            correct: 21   predicted: 29
# accuracy= 30 / 50 = 0.6
#
# --------------------------------------------------
# Iteration 850
# Validation accuracy: 0.888199987411499
# expression: XLVI           correct: 46   predicted: 66
# expression: XLVII          correct: 47   predicted: 47   OK!
# accuracy= 30 / 50 = 0.6
#
# --------------------------------------------------
# Iteration 900
# Validation accuracy: 0.8899999856948853
# expression: LXVII          correct: 67   predicted: 67   OK!
# expression: CLXX           correct: 170  predicted: 170  OK!
# expression: LI             correct: 51   predicted: 51   OK!
# expression: XLVII          correct: 47   predicted: 47   OK!
# expression: LXIX           correct: 69   predicted: 69   OK!
# accuracy= 30 / 50 = 0.6
#
# --------------------------------------------------
# Iteration 950
# Validation accuracy: 0.8899999856948853
# expression: CLII           correct: 152  predicted: 152  OK!
# expression: XLIV           correct: 44   predicted: 44   OK!
# accuracy= 30 / 50 = 0.6
#
# --------------------------------------------------
# Iteration 1000
# Validation accuracy: 0.8899999856948853
# expression: CLI            correct: 151  predicted: 151  OK!
# expression: CLXXXIX        correct: 189  predicted: 181
# expression: LI             correct: 51   predicted: 51   OK!
# expression: LXIX           correct: 69   predicted: 69   OK!
# accuracy= 30 / 50 = 0.6
#
# --------------------------------------------------
# Iteration 1050
# Validation accuracy: 0.8899999856948853
# expression: CXXXIX         correct: 139  predicted: 131
# expression: CLI            correct: 151  predicted: 151  OK!
# expression: CXLV           correct: 145  predicted: 145  OK!
# expression: CXXVIII        correct: 128  predicted: 128  OK!
# expression: XLVII          correct: 47   predicted: 47   OK!
# expression: CXIII          correct: 113  predicted: 113  OK!
# expression: XCIII          correct: 93   predicted: 93   OK!
# expression: CXLVII         correct: 147  predicted: 147  OK!
# accuracy= 30 / 50 = 0.6
#
# --------------------------------------------------
# Iteration 1100
# Validation accuracy: 0.8899999856948853
# expression: CXVII          correct: 117  predicted: 117  OK!
# expression: XCI            correct: 91   predicted: 99
# expression: CLVIII         correct: 158  predicted: 158  OK!
# expression: XXXVII         correct: 37   predicted: 38
# expression: XLVII          correct: 47   predicted: 47   OK!
# expression: CXLVII         correct: 147  predicted: 147  OK!
# accuracy= 30 / 50 = 0.6
#
# --------------------------------------------------
# Iteration 1150
# Validation accuracy: 0.8899999856948853
# expression: CLV            correct: 155  predicted: 155  OK!
# expression: XCV            correct: 95   predicted: 60
# expression: XVII           correct: 17   predicted: 17   OK!
# expression: XLVII          correct: 47   predicted: 47   OK!
# expression: CLXXVIII       correct: 178  predicted: 188
# expression: XXI            correct: 21   predicted: 29
# accuracy= 30 / 50 = 0.6
#
# --------------------------------------------------
# Iteration 1200
# Validation accuracy: 0.8899999856948853
# expression: LXXXIII        correct: 83   predicted: 88
# expression: CLII           correct: 152  predicted: 152  OK!
# expression: CXIII          correct: 113  predicted: 113  OK!
# expression: LXXIII         correct: 73   predicted: 77
# accuracy= 30 / 50 = 0.6
#
# --------------------------------------------------
# Iteration 1250
# Validation accuracy: 0.8901999855041504
# expression: CLI            correct: 151  predicted: 151  OK!
# expression: CLII           correct: 152  predicted: 152  OK!
# expression: CLVIII         correct: 158  predicted: 158  OK!
# expression: CIII           correct: 103  predicted: 107
# expression: LXXIII         correct: 73   predicted: 77
# accuracy= 30 / 50 = 0.6
#
# --------------------------------------------------
# Iteration 1300
# Validation accuracy: 0.8924999833106995
# expression: CXXXIX         correct: 139  predicted: 131
# expression: LXXXVII        correct: 87   predicted: 88
# expression: XLVI           correct: 46   predicted: 66
# expression: CLXXI          correct: 171  predicted: 171  OK!
# expression: CLXXXIII       correct: 183  predicted: 183  OK!
# expression: CVIII          correct: 108  predicted: 107
# expression: CXLVII         correct: 147  predicted: 147  OK!
# accuracy= 31 / 50 = 0.62
#
# --------------------------------------------------
# Iteration 1350
# Validation accuracy: 0.8949999809265137
# expression: XCIV           correct: 94   predicted: 99
# expression: XCI            correct: 91   predicted: 99
# expression: CLXX           correct: 170  predicted: 170  OK!
# expression: CVI            correct: 106  predicted: 106  OK!
# expression: CXIII          correct: 113  predicted: 113  OK!
# accuracy= 31 / 50 = 0.62
#
# --------------------------------------------------
# Iteration 1400
# Validation accuracy: 0.8949999809265137
# expression: CXVII          correct: 117  predicted: 117  OK!
# expression: CLI            correct: 151  predicted: 151  OK!
# expression: CIX            correct: 109  predicted: 119
# expression: XVII           correct: 17   predicted: 17   OK!
# expression: CLII           correct: 152  predicted: 152  OK!
# expression: LXXV           correct: 75   predicted: 75   OK!
# expression: XLI            correct: 41   predicted: 41   OK!
# accuracy= 31 / 50 = 0.62
#
# --------------------------------------------------
# Iteration 1450
# Validation accuracy: 0.8949999809265137
# expression: CLVIII         correct: 158  predicted: 158  OK!
# expression: CIII           correct: 103  predicted: 107
# expression: XXI            correct: 21   predicted: 29
# accuracy= 31 / 50 = 0.62
#
# --------------------------------------------------
# Iteration 1500
# Validation accuracy: 0.8949999809265137
# expression: LI             correct: 51   predicted: 51   OK!
# expression: CXXVIII        correct: 128  predicted: 128  OK!
# expression: CLXIV          correct: 164  predicted: 164  OK!
# accuracy= 31 / 50 = 0.62
#
# --------------------------------------------------
# Iteration 1550
# Validation accuracy: 0.8949999809265137
# expression: CLI            correct: 151  predicted: 151  OK!
# accuracy= 31 / 50 = 0.62
#
# --------------------------------------------------
# Iteration 1600
# Validation accuracy: 0.8949999809265137
# expression: CXLV           correct: 145  predicted: 145  OK!
# accuracy= 31 / 50 = 0.62
#
# --------------------------------------------------
# Iteration 1650
# Validation accuracy: 0.8949999809265137
# expression: CLXX           correct: 170  predicted: 170  OK!
# expression: CLXXXIII       correct: 183  predicted: 183  OK!
# expression: CXLVII         correct: 147  predicted: 147  OK!
# accuracy= 31 / 50 = 0.62
#
# --------------------------------------------------
# Iteration 1700
# Validation accuracy: 0.8949999809265137
# expression: XCI            correct: 91   predicted: 99
# expression: XLVI           correct: 46   predicted: 66
# accuracy= 31 / 50 = 0.62
#
# --------------------------------------------------
# Iteration 1750
# Validation accuracy: 0.8980999779701233
# expression: LXVII          correct: 67   predicted: 67   OK!
# expression: CLXXXIX        correct: 189  predicted: 181
# expression: CXLIV          correct: 144  predicted: 144  OK!
# expression: CXXIX          correct: 129  predicted: 139
# expression: CIII           correct: 103  predicted: 107
# expression: LXIX           correct: 69   predicted: 69   OK!
# expression: CLXXVIII       correct: 178  predicted: 178  OK!
# accuracy= 31 / 50 = 0.62
#
# --------------------------------------------------
# Iteration 1800
# Validation accuracy: 0.8959999799728393
# expression: XCIV           correct: 94   predicted: 99
# expression: CLV            correct: 155  predicted: 155  OK!
# expression: LXXXIII        correct: 83   predicted: 88
# expression: XXXI           correct: 31   predicted: 39
# expression: LXXV           correct: 75   predicted: 75   OK!
# expression: LXXIII         correct: 73   predicted: 77
# accuracy= 31 / 50 = 0.62
#
# --------------------------------------------------
# Iteration 1850
# Validation accuracy: 0.8964999794960022
# expression: XCIV           correct: 94   predicted: 99
# expression: LXVII          correct: 67   predicted: 67   OK!
# expression: LXXXVII        correct: 87   predicted: 88
# expression: CLVIII         correct: 158  predicted: 158  OK!
# expression: CLXXVI         correct: 176  predicted: 176  OK!
# expression: LV             correct: 55   predicted: 55   OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 1900
# Validation accuracy: 0.8991999769210816
# expression: XCV            correct: 95   predicted: 60
# expression: XLI            correct: 41   predicted: 41   OK!
# expression: CVIII          correct: 108  predicted: 107
# expression: LV             correct: 55   predicted: 55   OK!
# expression: CLXIV          correct: 164  predicted: 164  OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 1950
# Validation accuracy: 0.8999999761581421
# expression: LXXVI          correct: 76   predicted: 76   OK!
# expression: LXXXVII        correct: 87   predicted: 88
# expression: CLXXXIII       correct: 183  predicted: 183  OK!
# expression: CXXXII         correct: 132  predicted: 132  OK!
# expression: XXXVII         correct: 37   predicted: 38
# expression: CXLVII         correct: 147  predicted: 147  OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 2000
# Validation accuracy: 0.8999999761581421
# expression: LI             correct: 51   predicted: 51   OK!
# expression: LV             correct: 55   predicted: 55   OK!
# expression: CXLVII         correct: 147  predicted: 147  OK!
# expression: XLIV           correct: 44   predicted: 44   OK!
# expression: XXI            correct: 21   predicted: 29
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 2050
# Validation accuracy: 0.8999999761581421
# expression: CXXXIX         correct: 139  predicted: 131
# expression: CXXVIII        correct: 128  predicted: 128  OK!
# expression: XLI            correct: 41   predicted: 41   OK!
# expression: LXIX           correct: 69   predicted: 69   OK!
# expression: XXIV           correct: 24   predicted: 24   OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 2100
# Validation accuracy: 0.8999999761581421
# expression: LXXI           correct: 71   predicted: 71   OK!
# expression: CLI            correct: 151  predicted: 151  OK!
# expression: XXXI           correct: 31   predicted: 39
# expression: LXXXVII        correct: 87   predicted: 88
# expression: XLVI           correct: 46   predicted: 46   OK!
# expression: CLXXI          correct: 171  predicted: 171  OK!
# expression: XLI            correct: 41   predicted: 41   OK!
# expression: CVIII          correct: 108  predicted: 107
# expression: LXXIII         correct: 73   predicted: 77
# expression: XLIV           correct: 44   predicted: 44   OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 2150
# Validation accuracy: 0.8999999761581421
# expression: CVIII          correct: 108  predicted: 107
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 2200
# Validation accuracy: 0.8999999761581421
# expression: CLI            correct: 151  predicted: 151  OK!
# expression: CIX            correct: 109  predicted: 119
# expression: CXXVIII        correct: 128  predicted: 128  OK!
# expression: CVIII          correct: 108  predicted: 107
# expression: CLXXVIII       correct: 178  predicted: 178  OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 2250
# Validation accuracy: 0.8999999761581421
# expression: LXXVI          correct: 76   predicted: 76   OK!
# expression: CXLIV          correct: 144  predicted: 144  OK!
# expression: CLVIII         correct: 158  predicted: 158  OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 2300
# Validation accuracy: 0.8999999761581421
# expression: CXXVIII        correct: 128  predicted: 128  OK!
# expression: LXXIII         correct: 73   predicted: 77
# expression: CLXIV          correct: 164  predicted: 164  OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 2350
# Validation accuracy: 0.8999999761581421
# expression: CIX            correct: 109  predicted: 119
# expression: CXLIV          correct: 144  predicted: 144  OK!
# expression: CXXVIII        correct: 128  predicted: 128  OK!
# expression: CLXIV          correct: 164  predicted: 164  OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 2400
# Validation accuracy: 0.8999999761581421
# expression: CXXXIX         correct: 139  predicted: 131
# expression: XCIV           correct: 94   predicted: 99
# expression: CXVII          correct: 117  predicted: 117  OK!
# expression: LXXXIII        correct: 83   predicted: 82
# expression: XCI            correct: 91   predicted: 99
# expression: CXLV           correct: 145  predicted: 145  OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 2450
# Validation accuracy: 0.8999999761581421
# expression: XCV            correct: 95   predicted: 60
# expression: CVI            correct: 106  predicted: 106  OK!
# expression: CXIII          correct: 113  predicted: 113  OK!
# expression: XCIII          correct: 93   predicted: 93   OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 2500
# Validation accuracy: 0.8999999761581421
# expression: XCIV           correct: 94   predicted: 99
# expression: CIX            correct: 109  predicted: 119
# expression: LI             correct: 51   predicted: 51   OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 2550
# Validation accuracy: 0.8999999761581421
# expression: CLXX           correct: 170  predicted: 170  OK!
# expression: CLXXVI         correct: 176  predicted: 176  OK!
# expression: CXXVIII        correct: 128  predicted: 128  OK!
# expression: CXIII          correct: 113  predicted: 113  OK!
# expression: CXXXIV         correct: 134  predicted: 139
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 2600
# Validation accuracy: 0.8995999765396118
# expression: CLI            correct: 151  predicted: 151  OK!
# expression: CLXX           correct: 170  predicted: 170  OK!
# expression: CVI            correct: 106  predicted: 106  OK!
# expression: CXXXII         correct: 132  predicted: 132  OK!
# expression: LXXIII         correct: 73   predicted: 77
# expression: XXI            correct: 21   predicted: 29
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 2650
# Validation accuracy: 0.8991999769210816
# expression: CXXXIX         correct: 139  predicted: 131
# expression: CLV            correct: 155  predicted: 155  OK!
# expression: LXVII          correct: 67   predicted: 67   OK!
# expression: XVII           correct: 17   predicted: 17   OK!
# expression: XCIII          correct: 93   predicted: 93   OK!
# expression: LXIX           correct: 69   predicted: 69   OK!
# expression: XLIV           correct: 44   predicted: 44   OK!
# expression: CLXIV          correct: 164  predicted: 164  OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 2700
# Validation accuracy: 0.8993999767303467
# expression: LXXXIII        correct: 83   predicted: 82
# expression: LXVII          correct: 67   predicted: 67   OK!
# expression: CLII           correct: 152  predicted: 152  OK!
# expression: XXXI           correct: 31   predicted: 39
# expression: LXXXVII        correct: 87   predicted: 88
# expression: CXXVIII        correct: 128  predicted: 128  OK!
# expression: CLXXVIII       correct: 178  predicted: 178  OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 2750
# Validation accuracy: 0.8982999777793884
# expression: CLI            correct: 151  predicted: 151  OK!
# expression: XCI            correct: 91   predicted: 99
# expression: CLVIII         correct: 158  predicted: 158  OK!
# expression: LXXV           correct: 75   predicted: 75   OK!
# expression: CXXIX          correct: 129  predicted: 139
# expression: LV             correct: 55   predicted: 55   OK!
# expression: CLXIV          correct: 164  predicted: 164  OK!
# expression: CLXXVIII       correct: 178  predicted: 178  OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 2800
# Validation accuracy: 0.8971999788284302
# expression: CXXXIX         correct: 139  predicted: 131
# expression: CXVII          correct: 117  predicted: 117  OK!
# expression: CLII           correct: 152  predicted: 152  OK!
# expression: CLXXXIII       correct: 183  predicted: 183  OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 2850
# Validation accuracy: 0.8971999788284302
# expression: CI             correct: 101  predicted: 10
# expression: CLII           correct: 152  predicted: 152  OK!
# expression: XXXI           correct: 31   predicted: 39
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 2900
# Validation accuracy: 0.8979999780654907
# expression: CLV            correct: 155  predicted: 155  OK!
# expression: XCV            correct: 95   predicted: 60
# expression: XVII           correct: 17   predicted: 17   OK!
# expression: LXXVI          correct: 76   predicted: 76   OK!
# expression: CXXIX          correct: 129  predicted: 139
# expression: CXXXII         correct: 132  predicted: 132  OK!
# expression: CIII           correct: 103  predicted: 107
# expression: XLVII          correct: 47   predicted: 47   OK!
# expression: CXIII          correct: 113  predicted: 113  OK!
# expression: CVIII          correct: 108  predicted: 107
# expression: LXXIII         correct: 73   predicted: 77
# expression: XXI            correct: 21   predicted: 29
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 2950
# Validation accuracy: 0.8986999773979187
# expression: CXXXIX         correct: 139  predicted: 131
# expression: CLII           correct: 152  predicted: 152  OK!
# accuracy= 31 / 50 = 0.62
#
# --------------------------------------------------
# Iteration 3000
# Validation accuracy: 0.8955999803543091
# expression: CLXXXIX        correct: 189  predicted: 181
# expression: XLVII          correct: 47   predicted: 47   OK!
# expression: LV             correct: 55   predicted: 55   OK!
# accuracy= 31 / 50 = 0.62
#
# --------------------------------------------------
# Iteration 3050
# Validation accuracy: 0.895399980545044
# expression: CXVII          correct: 117  predicted: 117  OK!
# expression: CLII           correct: 152  predicted: 152  OK!
# expression: XXIV           correct: 24   predicted: 24   OK!
# expression: XXI            correct: 21   predicted: 29
# accuracy= 31 / 50 = 0.62
#
# --------------------------------------------------
# Iteration 3100
# Validation accuracy: 0.8950999808311463
# expression: CLI            correct: 151  predicted: 151  OK!
# expression: XXXI           correct: 31   predicted: 39
# expression: XLVI           correct: 46   predicted: 46   OK!
# expression: CXXXII         correct: 132  predicted: 132  OK!
# expression: XXIV           correct: 24   predicted: 24   OK!
# accuracy= 31 / 50 = 0.62
#
# --------------------------------------------------
# Iteration 3150
# Validation accuracy: 0.8949999809265137
# expression: LXXVI          correct: 76   predicted: 76   OK!
# expression: CLII           correct: 152  predicted: 152  OK!
# expression: LI             correct: 51   predicted: 51   OK!
# expression: XXXI           correct: 31   predicted: 39
# expression: CXXXIV         correct: 134  predicted: 139
# accuracy= 31 / 50 = 0.62
#
# --------------------------------------------------
# Iteration 3200
# Validation accuracy: 0.8969999790191651
# expression: CXXXIX         correct: 139  predicted: 131
# expression: LXXVI          correct: 76   predicted: 76   OK!
# expression: LXXIII         correct: 73   predicted: 77
# expression: CLXIV          correct: 164  predicted: 164  OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 3250
# Validation accuracy: 0.8974999785423279
# expression: CLV            correct: 155  predicted: 155  OK!
# expression: LXXVI          correct: 76   predicted: 76   OK!
# expression: CXLV           correct: 145  predicted: 145  OK!
# expression: CIII           correct: 103  predicted: 107
# expression: LV             correct: 55   predicted: 55   OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 3300
# Validation accuracy: 0.8989999771118165
# expression: LXXI           correct: 71   predicted: 71   OK!
# expression: CXXXIV         correct: 134  predicted: 134  OK!
# expression: XLIV           correct: 44   predicted: 44   OK!
# expression: CLXXVIII       correct: 178  predicted: 178  OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 3350
# Validation accuracy: 0.8994999766349793
# expression: CLI            correct: 151  predicted: 151  OK!
# expression: CXXVIII        correct: 128  predicted: 128  OK!
# expression: LV             correct: 55   predicted: 55   OK!
# expression: XCIII          correct: 93   predicted: 93   OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 3400
# Validation accuracy: 0.8999999761581421
# expression: CIX            correct: 109  predicted: 119
# expression: LXXVI          correct: 76   predicted: 76   OK!
# expression: XLI            correct: 41   predicted: 41   OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 3450
# Validation accuracy: 0.8974999785423279
# expression: LXXI           correct: 71   predicted: 71   OK!
# expression: LXVII          correct: 67   predicted: 67   OK!
# expression: CVIII          correct: 108  predicted: 107
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 3500
# Validation accuracy: 0.8999999761581421
# expression: CLV            correct: 155  predicted: 155  OK!
# expression: LXXV           correct: 75   predicted: 75   OK!
# expression: CXXXIV         correct: 134  predicted: 134  OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 3550
# Validation accuracy: 0.8999999761581421
# expression: LXXXIII        correct: 83   predicted: 82
# expression: XCI            correct: 91   predicted: 99
# expression: CLII           correct: 152  predicted: 152  OK!
# expression: CLVIII         correct: 158  predicted: 158  OK!
# expression: CXXXII         correct: 132  predicted: 132  OK!
# expression: XXXVII         correct: 37   predicted: 38
# expression: XLI            correct: 41   predicted: 41   OK!
# expression: XLVII          correct: 47   predicted: 47   OK!
# expression: CXIII          correct: 113  predicted: 113  OK!
# expression: LXXIII         correct: 73   predicted: 77
# expression: CXLVII         correct: 147  predicted: 147  OK!
# expression: XXIV           correct: 24   predicted: 24   OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 3600
# Validation accuracy: 0.9001999759674072
# expression: CXVII          correct: 117  predicted: 117  OK!
# expression: CLXX           correct: 170  predicted: 170  OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 3650
# Validation accuracy: 0.9005999755859375
# expression: CIX            correct: 109  predicted: 119
# expression: CXXXIV         correct: 134  predicted: 134  OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 3700
# Validation accuracy: 0.9002999758720398
# expression: LXVII          correct: 67   predicted: 67   OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 3750
# Validation accuracy: 0.9001999759674072
# expression: CI             correct: 101  predicted: 100
# expression: LXVII          correct: 67   predicted: 67   OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 3800
# Validation accuracy: 0.9009999752044677
# expression: CLV            correct: 155  predicted: 155  OK!
# expression: LXXI           correct: 71   predicted: 71   OK!
# expression: LXXV           correct: 75   predicted: 75   OK!
# expression: XCVI           correct: 96   predicted: 72
# accuracy= 33 / 50 = 0.66
#
# --------------------------------------------------
# Iteration 3850
# Validation accuracy: 0.9023999738693237
# expression: CXXXIX         correct: 139  predicted: 131
# expression: XCV            correct: 95   predicted: 60
# expression: LXXXIII        correct: 83   predicted: 82
# expression: XXXVII         correct: 37   predicted: 38
# accuracy= 33 / 50 = 0.66
#
# --------------------------------------------------
# Iteration 3900
# Validation accuracy: 0.9007999753952026
# expression: LXXI           correct: 71   predicted: 71   OK!
# expression: LXXVI          correct: 76   predicted: 76   OK!
# expression: LI             correct: 51   predicted: 51   OK!
# expression: CLVIII         correct: 158  predicted: 158  OK!
# expression: CXIII          correct: 113  predicted: 112
# expression: CXLVII         correct: 147  predicted: 147  OK!
# expression: LXIX           correct: 69   predicted: 69   OK!
# expression: XXIV           correct: 24   predicted: 24   OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 3950
# Validation accuracy: 0.902099974155426
# expression: XVII           correct: 17   predicted: 17   OK!
# expression: CXLV           correct: 145  predicted: 145  OK!
# expression: CXXXII         correct: 132  predicted: 132  OK!
# expression: CXLVII         correct: 147  predicted: 147  OK!
# expression: CLXXVIII       correct: 178  predicted: 178  OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 4000
# Validation accuracy: 0.9038999724388123
# expression: XXIV           correct: 24   predicted: 24   OK!
# accuracy= 33 / 50 = 0.66
#
# --------------------------------------------------
# Iteration 4050
# Validation accuracy: 0.9036999726295472
# expression: CXVII          correct: 117  predicted: 117  OK!
# expression: CLXX           correct: 170  predicted: 170  OK!
# expression: XLVI           correct: 46   predicted: 46   OK!
# expression: XXXVII         correct: 37   predicted: 38
# expression: LV             correct: 55   predicted: 55   OK!
# expression: CXLVII         correct: 147  predicted: 147  OK!
# expression: CLXIV          correct: 164  predicted: 164  OK!
# expression: XXI            correct: 21   predicted: 29
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 4100
# Validation accuracy: 0.9008999752998352
# expression: CLV            correct: 155  predicted: 155  OK!
# expression: LXVII          correct: 67   predicted: 67   OK!
# expression: XCI            correct: 91   predicted: 99
# expression: CIX            correct: 109  predicted: 119
# expression: LXXVI          correct: 76   predicted: 76   OK!
# expression: LXIX           correct: 69   predicted: 69   OK!
# accuracy= 32 / 50 = 0.64
#
# --------------------------------------------------
# Iteration 4150
# Validation accuracy: 0.9041999804973603
# expression: CVI            correct: 106  predicted: 106  OK!
# expression: CXXXIV         correct: 134  predicted: 134  OK!
# expression: XXIV           correct: 24   predicted: 24   OK!
# accuracy= 33 / 50 = 0.66
#
# --------------------------------------------------
# Iteration 4200
# Validation accuracy: 0.903399976491928
# expression: LXXXVII        correct: 87   predicted: 88
# expression: CXXVIII        correct: 128  predicted: 128  OK!
# expression: CXIII          correct: 113  predicted: 113  OK!
# expression: CVIII          correct: 108  predicted: 10
# expression: LV             correct: 55   predicted: 55   OK!
# expression: XLIV           correct: 44   predicted: 44   OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 4250
# Validation accuracy: 0.906699994802475
# expression: XCI            correct: 91   predicted: 99
# expression: LXXV           correct: 75   predicted: 75   OK!
# expression: LXXIII         correct: 73   predicted: 77
# expression: XCVI           correct: 96   predicted: 72
# expression: CXLVII         correct: 147  predicted: 147  OK!
# accuracy= 33 / 50 = 0.66
#
# --------------------------------------------------
# Iteration 4300
# Validation accuracy: 0.9081000053882599
# expression: XCIV           correct: 94   predicted: 99
# expression: CI             correct: 101  predicted: 10
# expression: CLVIII         correct: 158  predicted: 158  OK!
# expression: CXIII          correct: 113  predicted: 113  OK!
# expression: CVIII          correct: 108  predicted: 10
# accuracy= 33 / 50 = 0.66
#
# --------------------------------------------------
# Iteration 4350
# Validation accuracy: 0.907900003194809
# expression: CLI            correct: 151  predicted: 151  OK!
# expression: CXXVIII        correct: 128  predicted: 128  OK!
# expression: XXXVII         correct: 37   predicted: 38
# expression: CVIII          correct: 108  predicted: 10
# expression: LXXIII         correct: 73   predicted: 77
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 4400
# Validation accuracy: 0.909400019645691
# expression: CLI            correct: 151  predicted: 151  OK!
# expression: LXXXIII        correct: 83   predicted: 82
# expression: LXVII          correct: 67   predicted: 67   OK!
# expression: CIX            correct: 109  predicted: 119
# expression: XLVII          correct: 47   predicted: 47   OK!
# expression: XCVI           correct: 96   predicted: 72
# expression: CXXXIV         correct: 134  predicted: 134  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 4450
# Validation accuracy: 0.9044999766349793
# expression: CXXXIX         correct: 139  predicted: 131
# expression: CLXX           correct: 170  predicted: 170  OK!
# expression: CIII           correct: 103  predicted: 107
# accuracy= 33 / 50 = 0.66
#
# --------------------------------------------------
# Iteration 4500
# Validation accuracy: 0.9062999856472015
# expression: CI             correct: 101  predicted: 10
# expression: CXVII          correct: 117  predicted: 117  OK!
# expression: LXVII          correct: 67   predicted: 67   OK!
# expression: XVII           correct: 17   predicted: 17   OK!
# expression: CVI            correct: 106  predicted: 106  OK!
# accuracy= 33 / 50 = 0.66
#
# --------------------------------------------------
# Iteration 4550
# Validation accuracy: 0.9073999977111816
# expression: CIX            correct: 109  predicted: 119
# expression: CLXXI          correct: 171  predicted: 171  OK!
# expression: CLXXVI         correct: 176  predicted: 176  OK!
# expression: CXXXIV         correct: 134  predicted: 134  OK!
# accuracy= 33 / 50 = 0.66
#
# --------------------------------------------------
# Iteration 4600
# Validation accuracy: 0.9061999845504761
# expression: CXLV           correct: 145  predicted: 145  OK!
# expression: CVIII          correct: 108  predicted: 10
# expression: LXIX           correct: 69   predicted: 69   OK!
# accuracy= 33 / 50 = 0.66
#
# --------------------------------------------------
# Iteration 4650
# Validation accuracy: 0.9070999944210052
# expression: CIX            correct: 109  predicted: 119
# expression: LXXVI          correct: 76   predicted: 76   OK!
# expression: CXXXII         correct: 132  predicted: 132  OK!
# expression: XCVI           correct: 96   predicted: 72
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 4700
# Validation accuracy: 0.909400019645691
# expression: XCV            correct: 95   predicted: 60
# expression: CLXXXIX        correct: 189  predicted: 181
# expression: XXXI           correct: 31   predicted: 39
# expression: LXXXVII        correct: 87   predicted: 88
# expression: CXLVII         correct: 147  predicted: 147  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 4750
# Validation accuracy: 0.9072999966144562
# expression: XLVI           correct: 46   predicted: 46   OK!
# expression: XXI            correct: 21   predicted: 29
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 4800
# Validation accuracy: 0.9087000119686127
# expression: CXVII          correct: 117  predicted: 117  OK!
# expression: LXXVI          correct: 76   predicted: 76   OK!
# expression: CLXXVI         correct: 176  predicted: 176  OK!
# expression: CIII           correct: 103  predicted: 10
# expression: LV             correct: 55   predicted: 55   OK!
# expression: CXXXIV         correct: 134  predicted: 134  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 4850
# Validation accuracy: 0.9100000262260437
# expression: LI             correct: 51   predicted: 51   OK!
# expression: XLI            correct: 41   predicted: 41   OK!
# expression: CVIII          correct: 108  predicted: 10
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 4900
# Validation accuracy: 0.9086000108718872
# expression: LXXVI          correct: 76   predicted: 76   OK!
# expression: XLVII          correct: 47   predicted: 47   OK!
# expression: CXIII          correct: 113  predicted: 113  OK!
# expression: LXIX           correct: 69   predicted: 69   OK!
# expression: XXIV           correct: 24   predicted: 24   OK!
# expression: CLXXVIII       correct: 178  predicted: 178  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 4950
# Validation accuracy: 0.9100000262260437
# expression: LXXI           correct: 71   predicted: 71   OK!
# expression: CIX            correct: 109  predicted: 119
# expression: CLXXXIII       correct: 183  predicted: 183  OK!
# expression: XLVII          correct: 47   predicted: 47   OK!
# expression: LXXIII         correct: 73   predicted: 77
# expression: XCIII          correct: 93   predicted: 93   OK!
# expression: XLIV           correct: 44   predicted: 44   OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 5000
# Validation accuracy: 0.9075999999046326
# expression: CLV            correct: 155  predicted: 155  OK!
# expression: CLXX           correct: 170  predicted: 170  OK!
# expression: XVII           correct: 17   predicted: 17   OK!
# expression: XLVII          correct: 47   predicted: 47   OK!
# accuracy= 33 / 50 = 0.66
#
# --------------------------------------------------
# Iteration 5050
# Validation accuracy: 0.909000015258789
# expression: CLI            correct: 151  predicted: 151  OK!
# expression: LXVII          correct: 67   predicted: 67   OK!
# expression: CLII           correct: 152  predicted: 152  OK!
# expression: CLXXVI         correct: 176  predicted: 176  OK!
# expression: CXXVIII        correct: 128  predicted: 128  OK!
# expression: CVIII          correct: 108  predicted: 10
# expression: CXLVII         correct: 147  predicted: 147  OK!
# expression: XLIV           correct: 44   predicted: 44   OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 5100
# Validation accuracy: 0.9070999944210052
# expression: CLI            correct: 151  predicted: 151  OK!
# expression: CXLVII         correct: 147  predicted: 147  OK!
# expression: LXIX           correct: 69   predicted: 69   OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 5150
# Validation accuracy: 0.9087000119686127
# expression: CLVIII         correct: 158  predicted: 158  OK!
# expression: CXXIX          correct: 129  predicted: 129  OK!
# expression: XCIII          correct: 93   predicted: 93   OK!
# expression: CXLVII         correct: 147  predicted: 147  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 5200
# Validation accuracy: 0.9095000207424164
# expression: CXVII          correct: 117  predicted: 117  OK!
# expression: CXLV           correct: 145  predicted: 145  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 5250
# Validation accuracy: 0.9100000262260437
# expression: LXXXIII        correct: 83   predicted: 82
# expression: LXVII          correct: 67   predicted: 67   OK!
# expression: CLII           correct: 152  predicted: 152  OK!
# expression: CLXXI          correct: 171  predicted: 171  OK!
# expression: CXIII          correct: 113  predicted: 113  OK!
# expression: CXLVII         correct: 147  predicted: 147  OK!
# expression: CLXXVIII       correct: 178  predicted: 178  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 5300
# Validation accuracy: 0.9100000262260437
# expression: XVII           correct: 17   predicted: 17   OK!
# expression: CLII           correct: 152  predicted: 152  OK!
# expression: CIII           correct: 103  predicted: 10
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 5350
# Validation accuracy: 0.9100000262260437
# expression: XLVI           correct: 46   predicted: 46   OK!
# expression: CLXXXIII       correct: 183  predicted: 183  OK!
# expression: XLI            correct: 41   predicted: 41   OK!
# expression: CVIII          correct: 108  predicted: 10
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 5400
# Validation accuracy: 0.9100000262260437
# expression: XLVI           correct: 46   predicted: 46   OK!
# expression: LXXV           correct: 75   predicted: 75   OK!
# expression: XLI            correct: 41   predicted: 41   OK!
# expression: LV             correct: 55   predicted: 55   OK!
# expression: LXXIII         correct: 73   predicted: 77
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 5450
# Validation accuracy: 0.9100000262260437
# expression: CLXXXIX        correct: 189  predicted: 181
# expression: CIX            correct: 109  predicted: 119
# expression: XXXI           correct: 31   predicted: 39
# expression: CXXIX          correct: 129  predicted: 129  OK!
# expression: XLI            correct: 41   predicted: 41   OK!
# expression: XXIV           correct: 24   predicted: 24   OK!
# expression: CLXIV          correct: 164  predicted: 164  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 5500
# Validation accuracy: 0.9100000262260437
# expression: LI             correct: 51   predicted: 51   OK!
# expression: CLXXXIII       correct: 183  predicted: 183  OK!
# expression: CXLVII         correct: 147  predicted: 147  OK!
# expression: XXI            correct: 21   predicted: 29
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 5550
# Validation accuracy: 0.9100000262260437
# expression: XCIV           correct: 94   predicted: 99
# expression: CLV            correct: 155  predicted: 155  OK!
# expression: LXXVI          correct: 76   predicted: 76   OK!
# expression: LXXXVII        correct: 87   predicted: 88
# expression: CLXXVI         correct: 176  predicted: 176  OK!
# expression: XXXVII         correct: 37   predicted: 38
# expression: LXIX           correct: 69   predicted: 69   OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 5600
# Validation accuracy: 0.9100000262260437
# expression: LXXI           correct: 71   predicted: 71   OK!
# expression: CXLV           correct: 145  predicted: 145  OK!
# expression: XXXVII         correct: 37   predicted: 38
# expression: CVIII          correct: 108  predicted: 10
# expression: LV             correct: 55   predicted: 55   OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 5650
# Validation accuracy: 0.9100000262260437
# expression: XCIV           correct: 94   predicted: 99
# expression: CI             correct: 101  predicted: 10
# expression: CLXXXIX        correct: 189  predicted: 181
# expression: CLXXXIII       correct: 183  predicted: 183  OK!
# expression: CXLV           correct: 145  predicted: 145  OK!
# expression: CXXIX          correct: 129  predicted: 129  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# ...
# expression: CXLVII         correct: 147  predicted: 147  OK!
# expression: LXIX           correct: 69   predicted: 69   OK!
# expression: CLXXVIII       correct: 178  predicted: 178  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 8150
# Validation accuracy: 0.9100000262260437
# expression: CXXXIX         correct: 139  predicted: 131
# expression: CI             correct: 101  predicted: 10
# expression: CXLIV          correct: 144  predicted: 144  OK!
# expression: CVIII          correct: 108  predicted: 10
# expression: LV             correct: 55   predicted: 55   OK!
# expression: CXXXIV         correct: 134  predicted: 134  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 8200
# Validation accuracy: 0.9100000262260437
# expression: CXXXIX         correct: 139  predicted: 131
# expression: LXXI           correct: 71   predicted: 71   OK!
# expression: CXLIV          correct: 144  predicted: 144  OK!
# expression: CIII           correct: 103  predicted: 10
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 8250
# Validation accuracy: 0.9100000262260437
# expression: CXVII          correct: 117  predicted: 117  OK!
# expression: LI             correct: 51   predicted: 51   OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 8300
# Validation accuracy: 0.9100000262260437
# expression: LXXI           correct: 71   predicted: 71   OK!
# expression: LXVII          correct: 67   predicted: 67   OK!
# expression: LXIX           correct: 69   predicted: 69   OK!
# expression: CLXXVIII       correct: 178  predicted: 178  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 8350
# Validation accuracy: 0.9100000262260437
# expression: LXVII          correct: 67   predicted: 67   OK!
# expression: CLII           correct: 152  predicted: 152  OK!
# expression: LI             correct: 51   predicted: 51   OK!
# expression: CXXIX          correct: 129  predicted: 129  OK!
# expression: CXXXII         correct: 132  predicted: 132  OK!
# expression: CXXXIV         correct: 134  predicted: 134  OK!
# expression: XXI            correct: 21   predicted: 29
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 8400
# Validation accuracy: 0.9100000262260437
# expression: CI             correct: 101  predicted: 10
# expression: CLI            correct: 151  predicted: 151  OK!
# expression: CIX            correct: 109  predicted: 119
# expression: LI             correct: 51   predicted: 51   OK!
# expression: LXXV           correct: 75   predicted: 75   OK!
# expression: CLXXXIII       correct: 183  predicted: 183  OK!
# expression: CXXIX          correct: 129  predicted: 129  OK!
# expression: XXIV           correct: 24   predicted: 24   OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 8450
# Validation accuracy: 0.9100000262260437
# expression: XCIV           correct: 94   predicted: 99
# expression: CLI            correct: 151  predicted: 151  OK!
# expression: LXXXVII        correct: 87   predicted: 88
# expression: XLVI           correct: 46   predicted: 46   OK!
# expression: CLVIII         correct: 158  predicted: 158  OK!
# expression: XXXVII         correct: 37   predicted: 38
# expression: XXIV           correct: 24   predicted: 24   OK!
# expression: XXI            correct: 21   predicted: 29
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 8500
# Validation accuracy: 0.9100000262260437
# expression: LXXI           correct: 71   predicted: 71   OK!
# expression: XLVI           correct: 46   predicted: 46   OK!
# expression: CLXXVI         correct: 176  predicted: 176  OK!
# expression: CXXIX          correct: 129  predicted: 129  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 8550
# Validation accuracy: 0.9100000262260437
# expression: CXXXIX         correct: 139  predicted: 131
# expression: XCI            correct: 91   predicted: 99
# expression: CXLIV          correct: 144  predicted: 144  OK!
# expression: LXXV           correct: 75   predicted: 75   OK!
# expression: CXXXIV         correct: 134  predicted: 134  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 8600
# Validation accuracy: 0.9100000262260437
# expression: XCV            correct: 95   predicted: 60
# expression: LXXXIII        correct: 83   predicted: 82
# expression: XXXI           correct: 31   predicted: 39
# expression: CLXXVI         correct: 176  predicted: 176  OK!
# expression: XLI            correct: 41   predicted: 41   OK!
# expression: XLVII          correct: 47   predicted: 47   OK!
# expression: XCVI           correct: 96   predicted: 72
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 8650
# Validation accuracy: 0.9100000262260437
# expression: CXXXIX         correct: 139  predicted: 131
# expression: XCIV           correct: 94   predicted: 99
# expression: XCV            correct: 95   predicted: 60
# expression: LXXVI          correct: 76   predicted: 76   OK!
# expression: CVI            correct: 106  predicted: 106  OK!
# expression: LXIX           correct: 69   predicted: 69   OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 8700
# Validation accuracy: 0.9100000262260437
# expression: CLV            correct: 155  predicted: 155  OK!
# expression: LXVII          correct: 67   predicted: 67   OK!
# expression: XLVI           correct: 46   predicted: 46   OK!
# expression: CLXXVI         correct: 176  predicted: 176  OK!
# expression: XLI            correct: 41   predicted: 41   OK!
# expression: XXIV           correct: 24   predicted: 24   OK!
# expression: CLXIV          correct: 164  predicted: 164  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 8750
# Validation accuracy: 0.9100000262260437
# expression: CLV            correct: 155  predicted: 155  OK!
# expression: CXVII          correct: 117  predicted: 117  OK!
# expression: LXXI           correct: 71   predicted: 71   OK!
# expression: XCI            correct: 91   predicted: 99
# expression: XVII           correct: 17   predicted: 17   OK!
# expression: CLVIII         correct: 158  predicted: 158  OK!
# expression: LXXIII         correct: 73   predicted: 77
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 8800
# Validation accuracy: 0.9100000262260437
# expression: CXXIX          correct: 129  predicted: 129  OK!
# expression: CXXVIII        correct: 128  predicted: 128  OK!
# expression: CXLVII         correct: 147  predicted: 147  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 8850
# Validation accuracy: 0.9100000262260437
# expression: CLI            correct: 151  predicted: 151  OK!
# expression: LXXXIII        correct: 83   predicted: 82
# expression: CLXXI          correct: 171  predicted: 171  OK!
# expression: XCVI           correct: 96   predicted: 72
# expression: CXXXIV         correct: 134  predicted: 134  OK!
# expression: XXI            correct: 21   predicted: 29
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 8900
# Validation accuracy: 0.9100000262260437
# expression: CLXXI          correct: 171  predicted: 171  OK!
# expression: XLVII          correct: 47   predicted: 47   OK!
# expression: XCVI           correct: 96   predicted: 72
# expression: CXXXIV         correct: 134  predicted: 134  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 8950
# Validation accuracy: 0.9100000262260437
# expression: CXXXIX         correct: 139  predicted: 131
# expression: CLXXXIII       correct: 183  predicted: 183  OK!
# expression: XXIV           correct: 24   predicted: 24   OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 9000
# Validation accuracy: 0.9100000262260437
# expression: XCV            correct: 95   predicted: 60
# expression: CLII           correct: 152  predicted: 152  OK!
# expression: XLVII          correct: 47   predicted: 47   OK!
# expression: LV             correct: 55   predicted: 55   OK!
# expression: XCIII          correct: 93   predicted: 93   OK!
# expression: LXIX           correct: 69   predicted: 69   OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 9050
# Validation accuracy: 0.9100000262260437
# expression: XVII           correct: 17   predicted: 17   OK!
# expression: XXXI           correct: 31   predicted: 39
# expression: CLXXI          correct: 171  predicted: 171  OK!
# expression: CLXXVI         correct: 176  predicted: 176  OK!
# expression: CIII           correct: 103  predicted: 10
# expression: CXIII          correct: 113  predicted: 113  OK!
# expression: LXIX           correct: 69   predicted: 69   OK!
# expression: XXIV           correct: 24   predicted: 24   OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 9100
# Validation accuracy: 0.9100000262260437
# expression: LXXI           correct: 71   predicted: 71   OK!
# expression: CLII           correct: 152  predicted: 152  OK!
# expression: LXXV           correct: 75   predicted: 75   OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 9150
# Validation accuracy: 0.9100000262260437
# expression: CXXXIX         correct: 139  predicted: 131
# expression: XCIV           correct: 94   predicted: 99
# expression: LXXI           correct: 71   predicted: 71   OK!
# expression: XXXI           correct: 31   predicted: 39
# expression: CLXXXIII       correct: 183  predicted: 183  OK!
# expression: CXXIX          correct: 129  predicted: 129  OK!
# expression: CXXVIII        correct: 128  predicted: 128  OK!
# expression: XLVII          correct: 47   predicted: 47   OK!
# expression: XXIV           correct: 24   predicted: 24   OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 9200
# Validation accuracy: 0.9100000262260437
# expression: CI             correct: 101  predicted: 10
# expression: XCV            correct: 95   predicted: 60
# expression: CVI            correct: 106  predicted: 106  OK!
# expression: LXXIII         correct: 73   predicted: 77
# expression: XCVI           correct: 96   predicted: 72
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 9250
# Validation accuracy: 0.9100000262260437
# expression: LXXXIII        correct: 83   predicted: 82
# expression: CLXX           correct: 170  predicted: 170  OK!
# expression: CVI            correct: 106  predicted: 106  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 9300
# Validation accuracy: 0.9100000262260437
# expression: LXXI           correct: 71   predicted: 71   OK!
# expression: CLXXVI         correct: 176  predicted: 176  OK!
# expression: CXLVII         correct: 147  predicted: 147  OK!
# expression: XXIV           correct: 24   predicted: 24   OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 9350
# Validation accuracy: 0.9100000262260437
# expression: CI             correct: 101  predicted: 10
# expression: LXXV           correct: 75   predicted: 75   OK!
# expression: XCVI           correct: 96   predicted: 72
# expression: CLXXVIII       correct: 178  predicted: 178  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 9400
# Validation accuracy: 0.9100000262260437
# expression: LXXI           correct: 71   predicted: 71   OK!
# expression: LXXV           correct: 75   predicted: 75   OK!
# expression: CLXXXIII       correct: 183  predicted: 183  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 9450
# Validation accuracy: 0.9100000262260437
# expression: LXVII          correct: 67   predicted: 67   OK!
# expression: LI             correct: 51   predicted: 51   OK!
# expression: XCVI           correct: 96   predicted: 72
# expression: LXIX           correct: 69   predicted: 69   OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 9500
# Validation accuracy: 0.9100000262260437
# expression: CLXXXIX        correct: 189  predicted: 181
# expression: CVI            correct: 106  predicted: 106  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 9550
# Validation accuracy: 0.9100000262260437
# expression: XXXI           correct: 31   predicted: 39
# expression: CXLV           correct: 145  predicted: 145  OK!
# expression: XXXVII         correct: 37   predicted: 38
# expression: CXIII          correct: 113  predicted: 113  OK!
# expression: XLIV           correct: 44   predicted: 44   OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 9600
# Validation accuracy: 0.9100000262260437
# expression: CXXVIII        correct: 128  predicted: 128  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 9650
# Validation accuracy: 0.9100000262260437
# expression: XCI            correct: 91   predicted: 99
# expression: XVII           correct: 17   predicted: 17   OK!
# expression: CXXXII         correct: 132  predicted: 132  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 9700
# Validation accuracy: 0.910400025844574
# expression: XCIV           correct: 94   predicted: 99
# expression: CXVII          correct: 117  predicted: 117  OK!
# expression: LXXV           correct: 75   predicted: 75   OK!
# expression: XLIV           correct: 44   predicted: 44   OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 9750
# Validation accuracy: 0.9143000221252442
# expression: CLV            correct: 155  predicted: 155  OK!
# expression: XCI            correct: 91   predicted: 99
# expression: XVII           correct: 17   predicted: 17   OK!
# expression: CVI            correct: 106  predicted: 106  OK!
# expression: CIII           correct: 103  predicted: 10
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 9800
# Validation accuracy: 0.9145000219345093
# expression: LXXXIII        correct: 83   predicted: 82
# expression: LXXVI          correct: 76   predicted: 76   OK!
# expression: CXLIV          correct: 144  predicted: 144  OK!
# expression: CLXXVI         correct: 176  predicted: 176  OK!
# expression: CXXIX          correct: 129  predicted: 129  OK!
# expression: CXIII          correct: 113  predicted: 113  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 9850
# Validation accuracy: 0.9150000214576721
# expression: CXXXIX         correct: 139  predicted: 131
# expression: LI             correct: 51   predicted: 51   OK!
# expression: XXXI           correct: 31   predicted: 39
# expression: LXXXVII        correct: 87   predicted: 88
# expression: CLXXVI         correct: 176  predicted: 176  OK!
# expression: CXXIX          correct: 129  predicted: 129  OK!
# expression: LXIX           correct: 69   predicted: 69   OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 9900
# Validation accuracy: 0.9150000214576721
# expression: XXXI           correct: 31   predicted: 39
# expression: XLVI           correct: 46   predicted: 46   OK!
# expression: CXXIX          correct: 129  predicted: 129  OK!
# accuracy= 34 / 50 = 0.68
#
# --------------------------------------------------
# Iteration 9950
# Validation accuracy: 0.9150000214576721
# expression: CXXXIX         correct: 139  predicted: 131
# expression: XCIV           correct: 94   predicted: 99
# expression: XVII           correct: 17   predicted: 17   OK!
# expression: CLII           correct: 152  predicted: 152  OK!
# expression: LXXIII         correct: 73   predicted: 77
# accuracy= 34 / 50 = 0.68
